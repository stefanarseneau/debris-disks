# %% [markdown]
# ## IR Excess Probabilities
#
# ---
#
# Trying to calculate the probability of a given star having an infrared excess in the previous file. Suppose there are two samples: white dwarfs with and without IR excesses. These are drawn from the distributions $f_1(x)$ and $f_0(x)$ for IR excess and non-IR excess respectively. Then by Bayes' theorem, we can calculate a posterior: $$P(f_1 | x) = \frac{p(x|f_1)p(f_1)}{p(x|f_1)p(f_1) + p(x|f_0)p(f_0)}$$
#
# Where $x$ are the values of the W1 and W2 deviations from the prior notebook. The prior probabilities $p(f_1)$ and $p(f_0)$ can be determined by figuring out how prevalent IR excesses are over all. In this notebook, I'm gonna try and use some fancy methods to calculate $p(x|f_1)$ and $p(x|f_0)$ in particular.

# %%
from astropy.table import Table
import pyphot
from pyphot import unit
import sys
sys.path.append('../corv/src')
import corv

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

plt.style.use('stefan.mplstyle')
# Out:
# building montreal da model
# could not find pickled WD models
# /Users/vedantchandra/0_research/01_sdss5/006_build_corv/data/comm_cat/
# star and exposure catalogs not found! check paths and run make_catalogs() if you want to use sdss functionality. otherwise ignore.

# %%
# Tremblay+2019
dist_catalog = Table.read('https://cdsarc.cds.unistra.fr/viz-bin/nph-Cat/fits?J/MNRAS/482/5222/tablea1.dat')
# Raddi+2022
wd_reference = Table.read('https://cdsarc.cds.unistra.fr/viz-bin/nph-Cat/fits?J/A+A/658/A22/table5.dat.gz')

# %%
wd_reference_2[:1]
# Out:
# <Table length=1>
# System logTeff e_logTeff   logg   e_logg ... SpType    RV     e_RV     Sample
#          [K]      [K]    [cm/s2] [cm/s2] ...         km / s  km / s
# int16  float64  float64  float64 float64 ... bytes5 float64 float64   bytes12
# ------ ------- --------- ------- ------- ... ------ ------- ------- ------------
#      1   4.066     0.015    7.58    0.09 ...  DA     -30.04   16.29 SDSS

# %%
plt.figure(figsize=(20,8))

plt.subplot(2,4,1)

teff_counts, teff_bins = np.histogram(10**wd_reference['logTeff'], bins = 250)
teff_counts = teff_counts / sum(teff_counts)
plt.hist(teff_bins[:-1], teff_bins, weights = teff_counts, color = 'k', histtype = 'step')

plt.ylabel('Probability')

plt.subplot(2,4,5)
teff_test = np.random.choice(teff_bins[1:], p=teff_counts, size = (5000))
plt.hist(teff_test, color = 'k', histtype = 'step')

plt.xlabel('$T_{eff}$ [K]')
plt.ylabel('N')



plt.subplot(2,4,2)

logg_counts, logg_bins = np.histogram(wd_reference['logg'], bins = 250)
logg_counts = logg_counts / sum(logg_counts)
plt.hist(logg_bins[:-1], logg_bins, weights = logg_counts, color = 'k', histtype = 'step')

plt.subplot(2,4,6)
logg_test = np.random.choice(logg_bins[1:], p=logg_counts, size = (5000))
plt.hist(logg_test, color = 'k', histtype = 'step')

plt.xlabel('$\log g$')




plt.subplot(2,4,3)

dist_counts, dist_bins = np.histogram(100 / dist_catalog['plx'], bins = 250)
dist_counts = dist_counts / sum(dist_counts)
plt.hist(dist_bins[:-1], dist_bins, weights = dist_counts, color = 'k', histtype = 'step')

plt.subplot(2,4,7)
dist_test = np.random.choice(dist_bins[1:], p=dist_counts, size = (5000))
plt.hist(dist_test, color = 'k', histtype = 'step')

plt.xlabel('Distance [pc]')



plt.subplot(2,4,4)

radius_counts, radius_bins = np.histogram(wd_reference['Radius'], bins = 100)
radius_counts = radius_counts / sum(radius_counts)
plt.hist(radius_bins[:-1], radius_bins, weights = radius_counts, color = 'k', histtype = 'step')

plt.subplot(2,4,8)
radius_test = np.random.choice(radius_bins[1:], p=radius_counts, size = (5000))
plt.hist(radius_test, color = 'k', histtype = 'step')

plt.xlabel('Radius [$R_\odot$]')
# Out:
# Text(0.5, 0, 'Radius [$R_\\odot$]')

# %%
from astropy.modeling.models import BlackBody
from astropy import units as u
from astropy.visualization import quantity_support

def draw_teff():
    teff = np.random.choice(teff_bins[1:], p=teff_counts)
    
    while (2000 > teff) or (teff > 130000):
        teff = np.random.choice(teff_bins[1:], p=teff_counts)
    
    return teff

def draw_logg():
    logg = np.random.choice(logg_bins[1:], p=logg_counts)
    
    while (7 > logg) or (logg > 9):
        logg = np.random.choice(logg_bins[1:], p=logg_counts)
        
    return logg

def draw_dist():
    dist = np.random.choice(dist_bins[1:], p=dist_counts)
    
    while (0 > dist) or (dist > 200):
        dist = np.random.choice(dist_bins[1:], p=dist_counts)
        
    return dist

def draw_radius():
    radius_test = np.random.choice(radius_bins[1:], p=radius_counts)
    
    return radius

def draw_ir_temp():
    return np.random.normal(2000, 750, 1)

# %%
import lmfit

lib = pyphot.get_library()
filters = [lib['Gaia_G'], lib['Gaia_BP'], lib['Gaia_RP'], lib['WISE_RSR_W1'], lib['WISE_RSR_W2']]
base_wavl, tremblay, table = corv.utils.build_montreal_da(path = '/home/sarsene1/corv/src/corv/models/montreal_da', flux_unit = 'flam')

def blackbody(wavl, teff): #, radius, distance):
    c = 2.99e8
    bb = BlackBody(temperature=teff*u.K, scale = 1* u.erg / (u.cm ** 2 * u.s * u.AA * u.sr))
    si = bb(wavl * u.AA)
        
    return si# / (2 * np.pi)  

def fetch_sample(params):
    teff, logg, ir_temp = params['teff'], params['logg'], params['ir_temp']
    
    if ir_temp != 0:
        spec = tremblay((teff, logg)) + blackbody(base_wavl, ir_temp).value
    else:
        spec = tremblay((teff, logg))
    
    fluxes = [filters[j].get_flux(base_wavl * unit['angstrom'], spec* unit['erg/s/cm**2/angstrom'], axis=1).to('erg/s/cm**2/angstrom').value for j in range(len(filters))]
    mags = [-2.5 * np.log10(fluxes[j]) - filters[j].Vega_zero_mag + np.random.normal(scale = 0.03) for j in range(len(filters))]
    
    bp_rp = (mags[1] - mags[2])
    rp_w1 = (mags[2] - mags[3])
    rp_w2 = (mags[2] - mags[4])
    
    return bp_rp, rp_w1, rp_w2

def simulate_data(n, ir_excess = False):
    teffs = []
    loggs = []
    ir_temps = []
    
    bp_rps = []
    rp_w1s = []
    rp_w2s = []
    
    for i in tqdm(range(n)):
        teff = draw_teff()
        logg = draw_logg()
        
        if ir_excess:
            ir_temp = draw_ir_temp()
        else:
            ir_temp = 0
            
        params = {'teff' : teff, 'logg' : logg, 'ir_temp' : ir_temp}
        teffs.append(teff)
        loggs.append(logg)
        ir_temps.append(ir_temp)
        
        bp_rp, rp_w1, rp_w2 = fetch_sample(params)
        
        bp_rps.append(bp_rp)
        rp_w1s.append(rp_w1)
        rp_w2s.append(rp_w2)
        
    return teffs, loggs, ir_temps, bp_rps, rp_w1s, rp_w2s

# %%
sample_size = 5000
p_xs = 0.07

n_xs = int(sample_size * p_xs)

teff, logg, ir_temp, bp_rp, rp_w1, rp_w2 = simulate_data(sample_size - n_xs)
w1_diff = []
w2_diff = []

xs_teff, xs_logg, xs_ir_temp, xs_bp_rp, xs_rp_w1, xs_rp_w2 = simulate_data(n_xs, ir_excess = True)
xs_w1_diff = []
xs_w2_diff = []

bp_rp_th = []
rp_w1_th = []
rp_w2_th = []

logg = 8
teffs = np.linspace(5000, 120000, 100)

for i in tqdm(range(len(teffs))):
    spec = tremblay((teffs[i], logg))
    
    fluxes = [filters[j].get_flux(base_wavl * unit['angstrom'], spec* unit['erg/s/cm**2/angstrom'], axis=1).to('erg/s/cm**2/angstrom').value for j in range(len(filters))]
    mags = [-2.5 * np.log10(fluxes[j]) - filters[j].Vega_zero_mag for j in range(len(filters))]
    
    bp_rp_th.append(mags[1] - mags[2])
    rp_w1_th.append(mags[2] - mags[3])
    rp_w2_th.append(mags[2] - mags[4])
    
w1_diff = rp_w1 - np.interp(bp_rp, bp_rp_th, rp_w1_th)
w2_diff = rp_w2 - np.interp(bp_rp, bp_rp_th, rp_w2_th)

xs_w1_diff = xs_rp_w1 - np.interp(xs_bp_rp, bp_rp_th, rp_w1_th)
xs_w2_diff = xs_rp_w2 - np.interp(xs_bp_rp, bp_rp_th, rp_w2_th)
# Out:
# ...
# 100%|██████████| 100/100 [00:02<00:00, 33.82it/s]

# %%
plt.figure(figsize=(15,12))

plt.subplot(2,2,1)

plt.title('Simulated Data')

plt.scatter(bp_rp, rp_w1, s = 3, c = 'k', alpha = 0.5)
plt.scatter(xs_bp_rp, xs_rp_w1, s = 3, c = 'teal', alpha = 1)
plt.plot(bp_rp_th, rp_w1_th, c='red', label='Warwick DA Track')

plt.xlabel('$B_p-R_p$, mag')
plt.ylabel('RP-W1, mag')

plt.subplot(2,2,2)

plt.hist(np.concatenate((w1_diff,xs_w1_diff)), color = 'k', histtype = 'step', bins = 100)
plt.hist(xs_w1_diff, color = 'teal', histtype = 'step', bins = 100)

#plt.axvline(x = 1.3)

plt.xlabel('RP - W1 Deviation')

plt.subplot(2,2,3)

plt.scatter(bp_rp, rp_w2, s = 3, c = 'k', alpha = 0.5)
plt.scatter(xs_bp_rp, xs_rp_w2, s = 3, c = 'teal', alpha = 1)
plt.plot(bp_rp_th, rp_w2_th, c='red', label='Warwick DA Track')

plt.xlabel('$B_p-R_p$, mag')
plt.ylabel('RP-W2, mag')

plt.subplot(2,2,4)

plt.hist(np.concatenate((w2_diff,xs_w2_diff)), color = 'k', histtype = 'step', bins = 100)
plt.hist(xs_w2_diff, color = 'teal', histtype = 'step', bins = 100)

#plt.axvline(x = 1.3)

plt.xlabel('RP - W2 Deviation')
# Out:
# Text(0.5, 0, 'RP - W2 Deviation')
